# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to /Users/andrewgarcia-
# [nltk_data]     schanz/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv("newsapi.env")
NEWS_API_KEY =  "764c70b0d77844ec94bf67ea78b8fbcd"

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(NEWS_API_KEY)

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Fetch the Ethereum news articles
ethereum_headlines = newsapi.get_everything(
    q="ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
ethereum_df = pd.DataFrame(ethereum_sentiments)

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.025366    0.040360    0.030810    0.928820
# std      0.351611    0.056582    0.051509    0.070643
# min     -0.812600    0.000000    0.000000    0.705000
# 25%     -0.121500    0.000000    0.000000    0.873000
# 50%      0.000000    0.000000    0.000000    0.930500
# 75%      0.318200    0.079000    0.060000    1.000000
# max      0.750600    0.218000    0.249000    1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.105736    0.048730    0.023770    0.927520
# std      0.348368    0.061032    0.044215    0.068794
# min     -0.812600    0.000000    0.000000    0.710000
# 25%      0.000000    0.000000    0.000000    0.878250
# 50%      0.000000    0.000000    0.000000    0.930000
# 75%      0.361200    0.080750    0.045750    1.000000
# max      0.848100    0.290000    0.249000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum with .048730
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum has the highest compund score coming in at .8481
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum has the highest postive score coming in at .2900

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
nltk.download('stopwords')
import re
# Out:
# [nltk_data] Downloading package stopwords to /Users/andrewgarcia-
# [nltk_data]     schanz/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
# Create a list of stopwords
# Expand the default stopwords list if necessary

lemmatizer = WordNetLemmatizer()
sw = stopwords.words('english')

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    words = word_tokenize(text)
    # Convert the words to lowercase
    regex = re.compile("[^a-zA-Z ]")
    # Remove the punctuation
    re_clean = regex.sub('', text)  
    # Remove the stopwords
    words = word_tokenize(re_clean)   
    # Lemmatize Words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]   
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    
    
    
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
nltk.download('wordnet')
nltk.download('punkt')

bitcoin_df['tokens'] = bitcoin_df.text.apply(tokenizer)
bitcoin_df.head()
# Out:
# [nltk_data] Downloading package wordnet to /Users/andrewgarcia-
# [nltk_data]     schanz/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/andrewgarcia-
# [nltk_data]     schanz/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                                 text  compound  positive  \
# 0  It's all about clean energy, it seems. \r\nElo...    0.6908     0.169
# 1  Filed under:\r\nThe supply chain attack has re...   -0.5719     0.111
# 2  Several crypto fans that descended on Miami, F...    0.5574     0.107
# 3  image copyrightGetty Images\r\nThe gang behind...   -0.6124     0.000
# 4  SAN SALVADOR, June 16 (Reuters) - El Salvador ...    0.1280     0.043
#
#    negative  neutral                                             tokens
# 0     0.000    0.831  [clean, energy, seemselon, musk, tesla, caused...
# 1     0.184    0.705  [filed, underthe, supply, chain, attack, ha, r...
# 2     0.000    0.893  [several, crypto, fan, descended, miami, flori...
# 3     0.143    0.857  [image, copyrightgetty, imagesthe, gang, behin...
# 4     0.000    0.957  [san, salvador, june, reuters, el, salvador, r...

# %%
# Create a new tokens column for Ethereum
ethereum_df['tokens'] = ethereum_df.text.apply(tokenizer)
ethereum_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  TL;DR: The Cryptocurrency with Ethereum and So...    0.0000     0.000
# 1  It wasn't long ago that your average person ha...   -0.2960     0.000
# 2  Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther ...    0.3612     0.110
# 3  Ether holders have "staked" more than $13 bill...    0.7717     0.194
# 4  Ether is the cryptocurrency of the ethereum ne...    0.6249     0.150
#
#    negative  neutral                                             tokens
# 0     0.000    1.000  [tldr, cryptocurrency, ethereum, solidity, blo...
# 1     0.061    0.939  [wasnt, long, ago, average, person, clue, nft,...
# 2     0.041    0.849  [bitcoin, ethereumyuriko, nakaoether, overtook...
# 3     0.000    0.806  [ether, holder, staked, billion, worth, crypto...
# 4     0.000    0.850  [ether, cryptocurrency, ethereum, networkphoto...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
btc_ngram = ngrams(tokenizer(bitcoin_df.text.str.cat()), n=2)
Counter(btc_ngram).most_common(10)
# Out:
# [(('june', 'reuters'), 23),
#  (('reuters', 'bitcoin'), 18),
#  (('charsby', 'reuters'), 15),
#  (('taken', 'june'), 13),
#  (('el', 'salvador'), 12),
#  (('world', 'biggest'), 12),
#  (('previous', 'closebitcoin'), 11),
#  (('closebitcoin', 'world'), 11),
#  (('biggest', 'bestknown'), 11),
#  (('june', 'reutersedgar'), 11)]

# %%
# Generate the Ethereum N-grams where N=2
ethereum_ngram = ngrams(tokenizer(ethereum_df.text.str.cat()), n=2)
Counter(ethereum_ngram).most_common(10)
# Out:
# [(('reuters', 'bitcoin'), 13),
#  (('world', 'biggest'), 12),
#  (('previous', 'closebitcoin'), 11),
#  (('closebitcoin', 'world'), 11),
#  (('biggest', 'bestknown'), 11),
#  (('nonfungible', 'token'), 10),
#  (('bestknown', 'cryptocurrency'), 10),
#  (('charsby', 'reuters'), 10),
#  (('taken', 'june'), 9),
#  (('june', 'reuters'), 9)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
top_btc_wrds = tokenizer(bitcoin_df.text.str.cat())
token_count(top_btc_wrds, 10)
# Out:
# [('bitcoin', 82),
#  ('reuters', 63),
#  ('june', 44),
#  ('cryptocurrency', 29),
#  ('el', 22),
#  ('monday', 22),
#  ('world', 21),
#  ('salvador', 19),
#  ('seen', 18),
#  ('illustration', 18)]

# %%
# Use token_count to get the top 10 words for Ethereum
top_eth_wrds = tokenizer(ethereum_df.text.str.cat())
token_count(top_eth_wrds, 10)
# Out:
# [('reuters', 36),
#  ('cryptocurrency', 34),
#  ('bitcoin', 34),
#  ('world', 24),
#  ('june', 21),
#  ('ethereum', 17),
#  ('token', 14),
#  ('biggest', 13),
#  ('seen', 12),
#  ('previous', 12)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
btc_wc = bitcoin_df['tokens'].astype(str)
b_wc = WordCloud().generate(' '.join(btc_wc))
plt.imshow(b_wc)

# %%
# Generate the Ethereum word cloud
eth_wc = ethereum_df['tokens'].astype(str)
e_wc = WordCloud().generate(' '.join(eth_wc))
plt.imshow(e_wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
#      |████████████████████████████████| 13.6 MB 7.8 MB/s eta 0:00:01    |▎                               | 133 kB 1.6 MB/s eta 0:00:09
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from en-core-web-sm==3.1.0) (3.1.0)
# Requirement already satisfied: jinja2 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.50.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.3.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.7 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.7)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.4)
# Requirement already satisfied: numpy>=1.15.0 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.20.1)
# Requirement already satisfied: setuptools in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (52.0.0.post20210125)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.25.1)
# Requirement already satisfied: pathy>=0.3.5 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.0)
# Requirement already satisfied: packaging>=20.0 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (20.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.10.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/andrewgarcia-schanz/opt/anaconda3/envs/alpacaenv/lib/python3.9/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.1.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
all_btc_text = bitcoin_df['text'].str.cat()
all_btc_text[:1000]
# Out:
# 'It\'s all about clean energy, it seems.\xa0\r\nElon Musk and Tesla caused ripples in the cryptocurrency market in the past few months, first by announcing that Tesla had bought $1.5 billion worth of bitcoi… [+2508 chars]Filed under:\r\nThe supply chain attack has reached over a thousand organizations.\r\nIllustration by Alex Castro / The Verge\r\nThree days after ransomware attackers started the holiday weekend by comprom… [+3376 chars]Several crypto fans that descended on Miami, Florida, last weekend for the largest bitcoin conference in history are now saying theyve tested positive for covid-19. \r\nLarry Cermak, research director … [+2389 chars]image copyrightGetty Images\r\nThe gang behind a "colossal" ransomware attack has demanded $70m (£50.5m) paid in Bitcoin in return for a "universal decryptor" that it says will unlock the files of all … [+4140 chars]SAN SALVADOR, June 16 (Reuters) - El Salvador will not replace the U.S. dollar with bitcoin as the legal tender, Finance Minister Alejandro Zela'

# %%
# Run the NER processor on all of the text
doc = nlp(all_btc_text)

# Add a title to the document
doc.user_data["title"] = "BTC NER WORD CLOUD"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">BTC NER WORD CLOUD</h2>
#
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  caused ripples in the cryptocurrency market in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past few months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , first by announcing that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had bought
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  /
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Verge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Three days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after ransomware attackers started
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the holiday weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by comprom… [+3376 chars]Several crypto fans that descended on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Miami
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  for the largest bitcoin conference in history are now saying theyve tested positive for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     covid-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Larry Cermak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , research director … [+2389 chars]image
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     copyrightGetty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>The gang behind a &quot;colossal&quot; ransomware attack has demanded
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $70m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     £50.5m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ) paid in Bitcoin in return for a &quot;universal decryptor&quot; that it says will unlock the files of all … [+4140 chars]SAN SALVADOR,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 16
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will not replace the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dollar with bitcoin as the legal tender, Finance Minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alejandro Zelaya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , as the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Central American
#     <span style="font-size: 0.8em; font-weight: bold; line-height:

# %%
# List all Entities
print([ent.text for ent in doc.ents if ent.label_])
# Out:
# ['Elon Musk', 'Tesla', 'the past few months', 'Tesla', '$1.5 billion', 'Alex Castro', 'The Verge', 'Three days', 'the holiday weekend', 'Miami', 'Florida', 'last weekend', 'covid-19', 'Larry Cermak', 'copyrightGetty Images', '$70m', '£50.5m', 'June 16', 'Reuters', 'El Salvador', 'U.S.', 'Alejandro Zelaya', 'Wednesday', 'Central American', 'June 23', 'Reuters', 'El Salvador', 'June 23', 'Reuters', 'El Salvador', 'Pr', 'Reuters', 'Reuters', 'El Salvador', 'U.S.', 'Alejandro Zelaya', 'Wednesday', 'the Central American', 'Monday', 'morning', 'earlier this year', 'Reuters', 'June 13', 'Reuters', '9.8%', '39,035.47', 'Sunday', '3,492.71', 'June 21', 'Reuters', 'Monday', 'China', 'Sichuan', 'as low as $32,288', 'first', 'March 15, 2021', 'REUTERS', 'Dado Ruvic/', 'June 30', 'Reuters', 'Reuters', 'FILE', 'June 7, 2021', 'REUTERS', 'Edgar Su/Illustration', 'Reuters', '5.71%', '5.71%', '35,210', '0600', 'Saturday', '2,131.11', '45.7%', '2021', '6', 'June 14, 2021', 'REUTERS', 'Edgar Su/IllustrationJune 25', 'Reuters', '7.37%', '32,094.44', 'Monday', 'China', 'June 21', 'Reuters', '8.57%', '32,540.35', '2011', 'Monday', '3,049.42', '49.9%', 'Reuters', 'June 21', 'Reuters', '8.57%', '32,540.35', '2011', 'Monday', '3,049.42', 'Reuters', 'FILE', 'June 7, 2021', 'REUTERS', 'Edgar Su/Illustration/File Photo', 'Reuters', '+304', 'Reuters', 'June 25', 'Reuters', '7.37%', '32,094.44', 'Friday', '2,554.88', '50.5', 'May 19, 2021', 'REUTERS', 'Dado Ruvic', 'Reuters', '5.17%', '33', '9.83 %', '39,035.47', 'Sunday', '3,492.71', '40.7%', 'year', '27', 'chars]SpaceX', 'Tesla', 'Elon Musk', 'Tesla', 'Gruenheide', 'Berlin', 'Germany', 'May 17, 2021', 'Elon Musk', 'Sund', 'up to $15 million', "Sotheby's", 'next month', 'first', 'Reuters', 'June 25', 'Reuters', '8.51%', '31,699.83', '22:04 GMT', 'Friday', '2,937.27', 'Reuters', 'June 13', 'Reuters', '5.11 %', '37,360.63', '18:10 GMT on', 'Sunday', '1,817.87', 'Reuters', 'June 13', 'Reuters', '9.83 %', '39,035.47', 'Sunday', '3,492.71', '5.11 %', '37,360.63', '18:10 GMT on', 'Sunday', '1,817.87', '34.7%', 'year', '27,7', 'Monday', 'China', 'Julian Satterthwaite', 'June 18', 'Reuters', '7%', '35,431.15', '20:02', 'GMT', 'Friday', '2,666.53', '45.4%', '8', 'Last week', 'El Salvadors', 'US', '$6 billion', 'two-week', '40,000', 'Monday', 'another weekend', 'Elon Musk', 'June 29, 2021', 'REUTERS', 'Dado Ruvic', 'Ju', 'two-week', '40,000', 'Monday', 'another weekend', 'Elon Musk', 'Tesla', 'two-week', '40,000', 'Monday', 'another weekend', 'Elon Musk', 'Gensler', 'the Securities and Exchange Commission', 'Chip Somodevilla/', 'US', 'Reuters', 'NEW YORK', 'June 16', 'Reuters', 'The World Bank', 'Wednesday', 'El Salvadors', 'June 14, 2021', 'REUTERS', 'Edgar Su/Illustration/File PhotoJune', '21', 'Reuters', 'Reuters', 'DUBAI', 'June 23', 'Reuters', 'The Bitcoin Fund', 'Nasdaq Dubai', 'Wednesday', 'first', 'Canadian', 'March 15, 2021', 'REUTERS', 'Dado Ruvic', 'June 23', 'Reuters', 'The Bitcoin Fund', 'Entrepreneur', 'Crypto Kids Camp', 'Los Angeles', 'CNBC', '26', 'five to 17', 'Bitcoin', 'Jorg', 'June 7, 2021', 'REUTERS', 'Edgar Su/Illustration/File PhotoJune', '25', 'Reuters', "El Salvador's", '2020', 'Concord Acquisition Corp', 'SPAC', 'El Salvadoran', 'El Zonte', 'one', 'two-week', 'Monday', 'CNBC', 'Jim Cramer', 'China', 'Sold almos', 'Reuters', 'their sixth consecutive week', 'Monday', 'CoinShares', 'China', 'months', 'more than half', 'China', 'June 7, 2021', 'REUTERS', 'Edgar Su/Illustration/File PhotoJune', '28', 'Reuters', "Cathie Wood's", 'ARK', 'Gravengaard', 'Athena Bitcoin Inc.', 'ATM', 'San Salvador', 'El Salvador', 'June 24, 2021', 'REUTERS', 'Jose Cabezas', 'Reuters', 'June 13', 'Reuters', 'Sunday', "+288 chars]China's", 'Yunnan province', 'Saturday', 'chars]NEW YORK', 'June 21', 'Reuters', 'their sixth consecutive week', 'Monday', 'CoinShares', 'Reuters', 'June 18', 'Reuters', 'Friday', 'Switzerland', 'two-week', 'China', '10 per cent', '32,350', '8:50 a.m.', 'New York', '13%', 'El Zonte', 'two ye ...

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
all_eth_text = ethereum_df['text'].str.cat()
all_eth_text[:1000]
# Out:
# 'TL;DR: The Cryptocurrency with Ethereum and Solidity Blockchain Developer Bundle is on sale for £21.25 as of June 17, saving you 97% on list price.\r\nIs everyone you know investing in cryptocurrency? … [+949 chars]It wasn\'t long ago that your average person had no clue what an NFT was. Nowadays, they\'re making headlines for selling for hundreds of thousands of bucks. Predictably, folks are learning about NFTs … [+3056 chars]Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther overtook bitcoin in the number of active addresses on its network on Friday, a sign that demand is faltering for the world\'s biggest cryptocurrency as its co… [+2727 chars]Ether holders have "staked" more than $13 billion worth of the cryptocurrency on the ethereum 2.0 network, as excitement builds around the overhaul of the system and the potential growth of the staki… [+1851 chars]Ether is the cryptocurrency of the ethereum network.\r\nPhotothek/Getty Images\r\nEther holders have "staked" more than $13 billion worth of the cryp'

# %%
# Run the NER processor on all of the text
doc = nlp(all_eth_text)

# Add a title to the document
doc.user_data["title"] = "ETHEREUM NER WORD CLOUD"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">ETHEREUM NER WORD CLOUD</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">TL;DR: The Cryptocurrency with Ethereum and Solidity Blockchain Developer Bundle is on sale for £
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21.25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  as of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , saving you
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     97%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# </br>Is everyone you know investing in cryptocurrency? … [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +949 chars]It
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  wasn't long ago that your average person had no clue what an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was. Nowadays, they're making headlines for selling for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hundreds of thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of bucks. Predictably, folks are learning about NFTs … [+3056 chars]Bitcoin and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yuriko Nakao
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Ether overtook bitcoin in the number of active addresses on its network on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a sign that demand is faltering for the world's biggest cryptocurrency as its co… [+2727 chars]Ether holders have &quot;staked&quot;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than $13 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of the cryptocurrency on the ethereum
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Photothek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Ether holders have &quot;staked&quot;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than $13 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of the cryptocurrency on the ethereum
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  network, as excitement … [+1935 chars]Major upgrades to the ethereum network could help turn crypto staking into a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $40 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  business by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2025
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , according to analysts at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JPMorgan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The staking industry in which users earn cryptocurrency … [+2320 chars]Sir
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tim Berners-Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , credited as the inventor of the World Wide Web, is selling the source code for his invention as an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sotheby's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , or non-fungible token, is a type of cryp… [+2698 chars]Two Ethereum-based protocols,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Keep Network
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">

# %%
# List all Entities
print([ent.text for ent in doc.ents if ent.label_])
# Out:
# ['21.25', 'June 17', '97%', '+949 chars]It', 'NFT', 'hundreds of thousands', 'Ethereum\r\n', 'Yuriko Nakao', 'Friday', 'more than $13 billion', '2.0', 'Photothek', 'more than $13 billion', '2.0', '$40 billion', '2025', 'JPMorgan', 'Tim Berners-Lee', 'NFT', "Sotheby's", 'NFT', 'Keep Network', 'NuCypher', 'Last week', 'NFT', '90 percent', 'recent weeks', 'recent months', '5.71%', '35,210', '0600', 'Saturday', '2,131.11', '45.7%', '2021', '6', 'AFP', 'Getty Images\r\nInvestors', 'the third week', 'February 2018', '9.83 %', '39,035.47', 'Sunday', '3,492.71', '40.7%', 'year', '27', 'Reuters', 'June 25', 'Reuters', '8.51%', '31,699.83', '22:04 GMT', 'Friday', '2,937.27', 'Reuters', 'June 13', 'Reuters', '5.11 %', '37,360.63', '18:10 GMT on', 'Sunday', '1,817.87', 'Reuters', 'June 13', 'Reuters', '9.83 %', '39,035.47', 'Sunday', '3,492.71', '5.11 %', '37,360.63', '18:10 GMT on', 'Sunday', '1,817.87', '34.7%', 'year', '27,7', 'Reuters', 'June 25', 'Reuters', '7.37%', '32,094.44', 'Friday', '2,554.88', '50.5', 'Reuters', 'FILE', 'June 7, 2021', 'REUTERS', 'Edgar Su/Illustration', 'Reuters', '5.71%', '21', 'Reuters', '8.57%', '32,540.35', '2011', 'Monday', '3,049.42', '49.9%', 'Reuters', 'June 21', 'Reuters', '8.57%', '32,540.35', '2011', 'Monday', '3,049.42', '18', 'Reuters', '7%', '35,431.15', '20:02', 'GMT', 'Friday', '2,666.53', '45.4%', 'Reuters', 'FILE', 'June 7, 2021', 'REUTERS', 'Edgar Su/Illustration/File Photo', 'Reuters', '+304', 'Hackaday', 'Proof of Work', 'Bitcoin, Ethereum', 'chars]NEW YORK', 'June 21', 'Reuters', 'their sixth consecutive week', 'Monday', 'CoinShares', 'June 21', 'Reuters', 'their sixth consecutive week', 'Monday', 'CoinShares', 'Reuters', 'their sixth consecutive week', 'Monday', 'CoinShares', 'China', 'May 19, 2021', 'REUTERS', 'Dado Ruvic', 'Reuters', '5.17%', '33', 'June 14, 2021', 'REUTERS', 'Edgar Su/IllustrationJune 25', 'Reuters', '7.37%', '32,094.44', 'the past year', 'Tesla', 'Finance Insider', 'American Express', 'June 14, 2021', 'REUTERS', 'Edgar Su/IllustrationJune 16', 'Reuters', 'MSC', 'Ethereum', 'February 3, 2018', 'REUTERS', 'Dado Ruvic/Illustration/File', 'June 28', '$13 million', 'Thursday', 'Singapore', 'Mark Cuban', 'Marc Benioff', 'Getty Images', 'Brendan McDermid', 'the Securities and Exchange Commission', 'Robinhood', 'Reuters', 'June 13', 'Reuters', '9.8%', '39,035.47', 'Sunday', '3,492.71', 'Reuters', 'FILE', 'June 2, 2021', 'REUTERS', '+996 chars]In February 2021', 'Figma', 'Dylan Fields', 'NFT', '$7.5 million', 'Twitter', 'Jack Dorsey', 'first', 'Twitter', 'NFT', '2,915,835.47', 'NFT', 'UK', 'an estimated 2.3 million', 'the Bank of England', 'Ethereum', 'June 14, 2021', 'REUTERS', 'Edgar Su/IllustrationJune', 'Wide', 'Tim Berners-Lee', 'the Mozilla Festival 2018', 'London', 'Britain', 'October 27, 2018', 'REUTERS', 'Simon DawsonLONDON', 'June 28', 'Reuters', 'a second straight week', '2020', 'Spanish', 'AI', '30,000', 'first', 'January 27', 'Spanish', 'AI', '24, 2021', 'DueIt', 'Tim Berners-Lee', '$2.8 million', '1,000', 'two days', 'Ethereum Name Service', 'Ethereum', '3rd', 'Barcroft Media', 'Getty Images\r\nDetectives', 'London', 'about $160 million', 'the Metropolitan Police', 'Thursday', 'six weeks', 'Friday', 'Elon Musk', '7:23 am ET', '57', 'the New York Stock Exchange', 'Drew Angerer/', '10', 'the Opening Bell', 'day', 'Spanish', 'AI', 'Applepartnered', 'Coinbase', 'Spanish', 'AI', '2020', 'Eric Gaillard', 'Reuters', 'Ethereum', 'June 14, 2021', 'REUTERS', 'Edgar Su/IllustrationMEXICO C', 'Tim Berners-Lee', 'Sothebys', 'just $1,000', 'Berner', 'Binance', 'June 28, 2021', 'REUTERS', 'Dado Ruvic/File', 'Reuters', 'MUMBAI', 'Reuters', 'Friday', 'chars]NEW YORK', 'June 28', 'Reuters', 'the last week of June', 'Mo', 'June 24', 'Reuters', 'Andy Murray', 'Wimbledon', '2013', 'AI', 'AI', 'NFT', '$69 million', 'Beeple', 'Entrepreneur', 'Blockchain', 'the year', 'a decade', 'quantum', 'CNBC.Bu', 'Finance Insider', 'American Express', 'Entrepreneur', 'Entrepreneur', 'US', 'Thursd ...

# %% [markdown]
# ---
